# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('new_data.csv')

# %%
df.head()
# Out:
#                                   id   type         datetime  reactions  \
# 0    134115277150304_204848470076984  video   4/22/2018 6:00        529
# 1   246675545449582_1004819752968487  photo  4/21/2018 22:45        150
# 2  1050855161656896_1572628822812858  video   4/21/2018 6:17        227
# 3    134115277150304_225963114632186  photo   4/21/2018 2:29        111
# 4  1050855161656896_1371362292939513  photo   4/18/2018 3:22        213
#
#    comments  shares  likes  loves  wows  hahas  sads  angrys
# 0       512     262    432     92     3      1     1       0
# 1         0       0    150      0     0      0     0       0
# 2       236      57    204     21     1      1     0       0
# 3         0       0    111      0     0      0     0       0
# 4         0       0    204      9     0      0     0       0

# %%
df.columns
# Out:
# Index(['id', 'type', 'datetime', 'reactions', 'comments', 'shares', 'likes',
#        'loves', 'wows', 'hahas', 'sads', 'angrys'],
#       dtype='object')

# %%
len(df)
# Out:
# 7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7052 entries, 0 to 7051
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         7052 non-null   object
#  1   type       7052 non-null   object
#  2   datetime   7052 non-null   object
#  3   reactions  7052 non-null   int64
#  4   comments   7052 non-null   int64
#  5   shares     7052 non-null   int64
#  6   likes      7052 non-null   int64
#  7   loves      7052 non-null   int64
#  8   wows       7052 non-null   int64
#  9   hahas      7052 non-null   int64
#  10  sads       7052 non-null   int64
#  11  angrys     7052 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 661.2+ KB

# %%
 df.dtypes['datetime']
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#          reactions      comments       shares        likes        loves  \
# count  7052.000000   7052.000000  7052.000000  7052.000000  7052.000000
# mean    230.235111    224.425837    40.051900   215.144356    12.744186
# std     462.652215    889.551939   131.614721   449.501072    39.987309
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%      17.000000      0.000000     0.000000    17.000000     0.000000
# 50%      60.000000      4.000000     0.000000    58.000000     0.000000
# 75%     219.000000     23.000000     4.000000   185.000000     3.000000
# max    4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#               wows        hahas         sads       angrys
# count  7052.000000  7052.000000  7052.000000  7052.000000
# mean      1.290272     0.696540     0.243761     0.113301
# std       8.718911     3.956625     1.596957     0.726787
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.isna().sum()
# Out:
# id           0
# type         0
# datetime     0
# reactions    0
# comments     0
# shares       0
# likes        0
# loves        0
# wows         0
# hahas        0
# sads         0
# angrys       0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                    id   type         datetime  reactions  \
# 7050  725980084255106_865743260278787  photo  10/22/2017 0:38       1005
# 7051  246675545449582_264089710374832  video  11/13/2017 8:00        287
#
#       comments  shares  likes  loves  wows  hahas  sads  angrys
# 7050        25       1    979     16     9      1     0       0
# 7051       916     286    165    119     0      1     1       1

# %%
df=df.drop_duplicates()
df
# Out:
#                                      id   type         datetime  reactions  \
# 0       134115277150304_204848470076984  video   4/22/2018 6:00        529
# 1      246675545449582_1004819752968487  photo  4/21/2018 22:45        150
# 2     1050855161656896_1572628822812858  video   4/21/2018 6:17        227
# 3       134115277150304_225963114632186  photo   4/21/2018 2:29        111
# 4     1050855161656896_1371362292939513  photo   4/18/2018 3:22        213
# ...                                 ...    ...              ...        ...
# 7045    134115277150304_205403326688165  photo   9/24/2016 2:58         89
# 7046    725980084255106_824100531109727  photo  9/23/2016 11:19         16
# 7047    246675545449582_365619913555144  photo  9/21/2016 23:03          2
# 7048  1050855161656896_1557792654296475  photo   9/20/2016 0:43        351
# 7049   246675545449582_1150847395032388  photo  9/10/2016 10:30         17
#
#       comments  shares  likes  loves  wows  hahas  sads  angrys
# ...

# %%
#Converting Object to Date time
import datetime

# %%
df['Date']= df['datetime'].apply(lambda x:datetime.datetime.strptime(x, '%m/%d/%Y %H:%M'))
df['Year'] =df['Date'].apply(lambda x: x.year)
df['Month'] = df['Date'].apply(lambda x: x.month)
df['Day'] = df['Date'].apply(lambda x: x.day)
df['Hour'] = df['Date'].apply(lambda x: x.hour)

# %%
df.head()
# Out:
#                                   id   type         datetime  reactions  \
# 0    134115277150304_204848470076984  video   4/22/2018 6:00        529
# 1   246675545449582_1004819752968487  photo  4/21/2018 22:45        150
# 2  1050855161656896_1572628822812858  video   4/21/2018 6:17        227
# 3    134115277150304_225963114632186  photo   4/21/2018 2:29        111
# 4  1050855161656896_1371362292939513  photo   4/18/2018 3:22        213
#
#    comments  shares  likes  loves  wows  hahas  sads  angrys  \
# 0       512     262    432     92     3      1     1       0
# 1         0       0    150      0     0      0     0       0
# 2       236      57    204     21     1      1     0       0
# 3         0       0    111      0     0      0     0       0
# 4         0       0    204      9     0      0     0       0
#
#                  Date  Year  Month  Day  Hour
# 0 2018-04-22 06:00:00  2018      4   22     6
# 1 2018-04-21 22:45:00  2018      4   21    22
# ...

# %%
#Engagement Score
df['Engement_Score'] = (df['reactions']+df['comments']+df['shares'])/3

# %%
# Data Visualization

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=df, x="Date", y="Engement_Score")
plt.xlabel('Date',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(data=df, x="Hour", y="Engement_Score")
plt.xlabel('Hour',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.barplot(data=df, x="Hour", y="shares")
plt.xlabel('Hour',fontsize=16)
plt.ylabel('Numer of Shares',fontsize=16)
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(data=df, x="Year", y="Engement_Score")
plt.xlabel('Year',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
# Out:
# Text(0, 0.5, 'Engement_Score')

# %%
plt.figure(figsize=(16, 10))
sns.barplot(data=df, x="Month", y="Engement_Score")
plt.xlim([1,12])
plt.xlabel('Month',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
# Out:
# Text(0, 0.5, 'Engement_Score')

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(data=df, x="Day", y="Engement_Score")
plt.xlabel('Day',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
# Out:
# Text(0, 0.5, 'Engement_Score')

# %%
plt.figure(figsize=(16, 10))
sns.barplot(data=df, x="type", y="Engement_Score")
plt.xlabel('Post Type',fontsize=16)
plt.ylabel('Engement_Score',fontsize=16)
# Out:
# Text(0, 0.5, 'Engement_Score')

# %%
sns.jointplot(x='reactions',y='likes',data=df)

# %%
df1=pd.pivot_table(df, index=['type'],values=['reactions','likes','wows','loves','hahas','sads','angrys'],aggfunc=np.sum)

# %%
df1['reactions (except like) %']= ((df1['reactions']-df1['likes'])/df1['reactions'])*100

# %%
df1
# Out:
#         angrys  hahas   likes  loves  reactions  sads  wows  \
# type
# link         0      2   23286     19      23319     0    12
# photo      196    818  766602   6197     777373   611  2936
# status       9     40  158968    570     160156   141   428
# video      593   4050  567198  82951     661478   966  5714
#
#         reactions (except like) %
# type
# link                     0.141516
# photo                    1.385564
# status                   0.741777
# video                   14.252931

# %%
df.groupby(['type']).sum()
# Out:
# C:\Users\seyed\AppData\Local\Temp\ipykernel_21332\3759102649.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['type']).sum()
#         reactions  comments  shares   likes  loves  wows  hahas  sads  angrys  \
# type
# link        23319       359     277   23286     19    12      2     0       0
# photo      777373     68580   10951  766602   6197  2936    818   611     196
# status     160156     13227     934  158968    570   428     40   141       9
# video      661478   1499544  269997  567198  82951  5714   4050   966     593
#
#            Year  Month    Day   Hour  Engement_Score
# type
# link     127042    355    980    700     7985.000000
# photo   8644849  28296  68903  34514   285634.666667
# status   736099   2428   5804   3055    58105.666667
# ...

# %%
data = df[['type','reactions',
       'comments', 'shares', 'likes', 'loves', 'wows',
       'hahas', 'sads', 'angrys', 'Date', 'Year', 'Month',
       'Day','Hour', 'Engement_Score']]

# %%
sns.pairplot(data)

# %%
corr = abs(data.corr())
round(corr,2)
# Out:
# C:\Users\seyed\AppData\Local\Temp\ipykernel_21332\3236562116.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = abs(data.corr())
#                 reactions  comments  shares  likes  loves  wows  hahas  sads  \
# reactions            1.00      0.15    0.25   0.99   0.31  0.27   0.18  0.08
# comments             0.15      1.00    0.64   0.10   0.52  0.16   0.33  0.24
# shares               0.25      0.64    1.00   0.17   0.82  0.41   0.40  0.20
# likes                0.99      0.10    0.17   1.00   0.21  0.21   0.12  0.05
# loves                0.31      0.52    0.82   0.21   1.00  0.51   0.51  0.21
# wows                 0.27      0.16    0.41   0.21   0.51  1.00   0.29  0.09
# hahas                0.18      0.33    0.40   0.12   0.51  0.29   1.00  0.14
# ...

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corr>0.6)
# Out:
# <Axes: >

# %%
# ...........Linear Regression............#

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[['Year','Month','Day','Hour']]
y = data['Engement_Score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
from sklearn import metrics

# %%
MAE = metrics.mean_absolute_error (y_test, predictions)
MSE = metrics.mean_squared_error (y_test, predictions)
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 210.76017466919015

# %%
MSE
# Out:
# 183957.7970641937

# %%
RMSE
# Out:
# 428.9030159187432

# %%
# ...........Support Vector Regression............#

# %%
X = data[['Year','Month','Day','Hour']]
y = data['Engement_Score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

# %%
# X_train = X_train.reshape(1, -1)
y_train= y_train.reshape(-1, 1)
# X_test = X_test.reshape(1, -1)
y_test= y_test.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X_train)
y = sc_y.fit_transform(y_train)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
# Out:
# C:\Users\seyed\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred = regressor.predict(X_test)
y_pred = y_pred.reshape(-1, 1)
y_pred = sc_y.inverse_transform(y_pred)

# %%
from sklearn import metrics

# %%
MAE = metrics.mean_absolute_error (y_test, y_pred)
MSE = metrics.mean_squared_error (y_test, y_pred)
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 170.62403521215901

# %%
MSE
# Out:
# 139756.4014931961

# %%
RMSE
# Out:
# 373.8400747554977
